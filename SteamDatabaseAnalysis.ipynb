# %% [markdown]
# <center> <h2> DS 3000 - Summer 2020</h2> </center>
# <center> <h3> DS Report </h3> </center>

# %% [markdown]
# <center> <h3>Steam Data Analysis and Game Popularity Prediction</h3> </center>
# <center><h4>Kimin Lee, Judy Zhang, Ethan Yu</h4></center>

# %% [markdown]
# <hr style="height:2px; border:none; color:black; background-color:black;">

# %% [markdown]
# #### Executive Summary:
#
# Add your summary here (100-150 words)
#
# Provide a brief summary of your project. After reading this executive summary, your readers should have a rough understanding of what you did in this project. You can think of this summary in terms of the four sections of the report and write 1-2 sentences describing each section.

# %% [markdown]
# <hr style="height:2px; border:none; color:black; background-color:black;">

# %% [markdown]
# ## Outline
# 1. <a href='#1'>INTRODUCTION</a>
# 2. <a href='#2'>METHOD</a>
# 3. <a href='#3'>RESULTS</a>
# 4. <a href='#4'>DISCUSSION</a>

# %% [markdown]
# <a id="1"></a>
# <hr style="height:2px; border:none; color:black; background-color:black;">

# %% [markdown]
# ## 1. INTRODUCTION

# %% [markdown]
# **Problem Statement**
#
# The topic of our project is to analyze and predict the effects of various game features on a game's popularity. In other words, predicting the popularity of a game being on sale on Steam.
#
# With the many factors that could possibly contribute to the success or failure of a game, lack of information as to how these factors truly influence a game's popularity make it difficult for game developers to developing games set up for success.
#
# In this project, we will use machine learning algorithms to identify which potential feature variables in our data has a significant relationship and impact on game popularity.
#
# **Significance of the Problem**
#
# As new games are constantly being developed, it is important for game developers to understand which aspects of a game fuel its popularity so that they can create more successful games. Tackling this problem will allow game developers to identify, understand, and apply the factors of what makes a game popular so that they can not only create more successful games, but also save time, money, and energy in the process. This data and analysis can be effectively used for the business of games, where a gaming company can predict the sales of a game that is to be released. This skill can be used to balance the company budget, improve their game advertisement, and further understand the marketing trend of the gaming market.
#
# **Research Questions**
#
# Given the aforementioned problem and its importance, we set out to tackle the following questions:
#
# * What features are significant enough to affect the prediction of all reviews if we analyze the prediction between the number of all positive reviews and the features?
# * If the popular_tags feature is significant enough to affect the prediction of all reviews, how does popular_tags affect the game popularity?
# * How does the number of all positive reviews affect the number of owners/ number of sales for the game?
# * Will the Lasso regression method have the highest testing accuracy compared to the Ridge, Knn, and the SVM regressions?
#
# **Hypotheses:**
#
#    * **Hypothesis about the number of popular tags and the number of positive reviews:**
#        * Null: The number of popular tags feature and number of positive reviews have no relationship.
#        * Alternative: The number of popular tags feature and number of positive reviews have a strong positigve linear relationship.
#
#    * **Hypothesis about the max number of owners and the number of positive reviews:**
#        * Null: The number max number of owners feature and number of positive reviews have no relationship.
#        * Alternative: The max number of owners feature and number of positive reviews have a strong positive linear relationship.
#
#    * **Hypothesis about the number of platforms supported and the number of positive reviews:**
#        * Null: The number of platforms supported feature and number of positive reviews have no relationship.
#        * Alternative: The number of platforms supported feature and number of positive reviews have a strong positive linear relationship.
#
#    * **Hypothesis about the month of the game release date being in a holiday season and the number of positive reviews:**
#        * Null: The month of the game release date being in a holiday season feature and number of positive reviews have no relationship.
#        * Alternative: The month of the game release date being in a holiday season will increase the number of positive reviews.
#
# ## Anova / F-Test
#
#
# ## RUBRIC
#
#
# In this section, orient your readers to your project. You've already written some of these in previous deliverables. Based on your final analysis, revise your problem statement and write a concise introduction section. This section should touch upon the following points, but should be written in full paragraphs. Your writing should incorporate all of these points (and more if you like) in a coherent way. Remember that you are trying to convince your readers that this is an important problem to tackle.
#
# Problem Statement
# * Describe the problem you would like to tackle.
# * What is the topic of your project?
# * What do you want to learn about it?
#
# Significance of the Problem
# * Why is it important to tackle this problem in your project?
# * In what ways could the insights from this project be useful?
# * **(optional)** Has there been previous work on your topic in terms of applying ML techniques to analyze similar datasets? Do some research into your topic. What algorithms were used? What was the performance of those algorithms? Cite your sources appropriately. You can use the numbered reference format or APA (if you are more comfortable with it).
#
# Questions/Hypothesis
# * End this section with a list of questions and hypotheses
# * You should tie these questions/hypotheses to the problem statement and its significance
#     * e.g. Given the aforementioned problem and its importance, we set out to tackle the following questions:
#
# **Requirement:**
# * You should have at least one question tapping into the comparison of various machine learning algorithms in predicting your target variable from your features variables.
# * You should have at least one hypothesis regarding the relationship between two variables.

# %% [markdown]
# <a id="2"></a>
# <hr style="height:2px; border:none; color:black; background-color:black;">

# %% [markdown]
# ## 2. METHOD

# %% [markdown]
# ### 2.1. Data Acquisition
#
# The datasets in this project contain information about various attributes and data for games that are on sale or have been on sale on Steam, a popular online game platform.
#
# We utilized two database sources for our project, https://www.kaggle.com/trolukovich/steam-games-complete-dataset/data and https://www.kaggle.com/nikdavis/steam-store-games , both of which include specific columns that don't exist in the other dataset. For example, one dataset includes data on the max owners, while the other includes the data on the game
# reviews.
#
# Thus, we merged the 2 datasets with the same game names to create one dataset/dataframe
# with the column attributes mentioned above. One dataset includes data for 40834 games, while the other
# includes data for 27076 games. So, at maximum, we will have data for 27076 games in our database.
#
# After merging the two dataframes, the complete list of variables, used in this project are as follows:
#
# * developer - String that represents the game developer
# * publisher - String that represents the game publisher
# * positive_reviews - Integer that represents the number of positive reviews
# * average_playtime - Integer that represents the average number of hours users have played the game
# * max_owners - Integer that represents the number of game owners allowed
# * price - Double that represents the price of a game in US dollars
# * support_windows - Integer (1 or 0) where 1 represents supported and 0 represented unsupported
# * support_mac - Integer (1 or 0) where 1 represents supported and 0 represented unsupported
# * support_linux - Integer (1 or 0) where 1 represents supported and 0 represented unsupported
# * release_year - Integer that represents the year the game was released
# * release_month - Integer that represents the month the game was released
# * popular_tags - List of Strings that represents a list of all the popular tags used on the game
# * languages - List of Strings that represents a list of all the supported languages on the game
# * is_released_on_holiday - Integer (1 or 0) where 1 represents released on holiday and 0 released not released on holiday
#
#
# ## RUBRIC
#
# * Describe where you obtained your data. Provide a link to the original source.
# * If you scraped your data, include your code as a separate script file.
# * Your data should be stored in an online repository (e.g., GitHub) and your code should retrieve your data from that online resource. You can read csv files from the Web in the same way that you read files from local drive.
# * Describe the dataset (i.e., what it is about) and the number of variables included.

# %% [markdown]
# ### 2.2. Variables
#
# * Hypothesis:
#    * **Hypothesis about the number of popular_tags and the number of positive reviews:**
#        * Independent variable: number of popular_tags
#        * Dependent variable: number of positive reviews
#
#    * **Hypothesis about the max number of owners and the number of positive reviews:**
#        * Independent variable: max number of owners
#        * Dependent variable: number of positive reviews
#
#    * **Hypothesis about the number of platforms supported and the number of positive reviews:**
#        * Independent variable: number of platforms supported
#        * Dependent variable: number of positive reviews
#
#    * **Hypothesis about the month of the game release date being in a holiday season and the positive reviews:**
#        * Independent variable: month of the game release date being in a holiday season
#        * Dependent variable: number of positive reviews
#
# * Predictive models:
#    * **Independent Variables (feature variables)**
#        * developer
#        * publisher
#        * average_playtime
#        * max_owners
#        * price
#        * support_windows
#        * support_mac
#        * support_linux
#        * release_year
#        * release_month
#        * popular_tags
#        * languages
#        * is_released_on_holiday
#    * **Dependent Variables (target variable)**
#        * positive_reviews
#
# **Rationale**
#
# Our target variable is the number of positive reviews for the game. We are identifying this variable
# to be the identifier to determine the game’s popularity, as more popular games will contain more positive
# reviews. We decided not to look at the ratio of the reviews between positive and negative reviews, since
# popular games will have more players, and thus have more raw count for positive reviews. As stated above, the rest of the variables listed are the feature variables.

# %% [markdown]
# ### 2.3. Data Analysis
#
# **Predictive Model**
#
# Our project is going to tackle a regression problem. We are going to be predicting the number of positive_reviews given the other feature variables provided for a game.
#
# **Machine Learning Algorithms**
#
# We are planning to use Lasso and XGBoost as
# our machine learning algorithms. Lasso will also be a feature extraction, and engineering technique to
# identify which features are significant to have an impact/relationship to the prediction of the number of
# positive_reviews.
#
#
# ## RUBRIC
# * Specifically describe your predictive model. What outcome variable are you going to predict from what feature variables? Why do you think those are important predictors?
# * Describe why this is a supervised ML problem and identify the sub-category of the learning task (e.g. classification).
# * What machine learning algorithms are you going to use? **Why?**

# %% [markdown]
# <a id="3"></a>
# <hr style="height:2px; border:none; color:black; background-color:black;">

# %% [markdown]
# ## 3. RESULTS

# %% [markdown]
# ### 3.1. Data Wrangling
# In this section, you should do the following and explain why you are doing what you are doing. For each, you should include your code in a cell, followed by a sample output. For instance, if you are one-hot encoding one of your variables, you should first describe what it is and why you are doing it. You should then include your code in a cell, and the sample output should be available as well.
#
# * Perform simple data cleaning (delete extra columns, deal with NA values, etc.)
# * Perform data wrangling to get your features and target values (e.g., grouping your dataframe by columns, applying functions to format dataframes, etc.)
# * Preprocess your variables (e.g., scaling/transforming feature variables to normalize them)
# * Perform feature extraction (dummy variables, new features from existing features, etc.)
# * Use one feature selection technique to select a subset of your original features

# %% [markdown]
# ###  Dataset 1

# %%
import pandas as pd

# First dataset
df1 = pd.read_csv('steam.csv')

# Rename column name "owners" to "max_owners", "positive_ratings" to "positive_reviews", 
# "negative_ratings" to "negative_reviews"
df1.rename(columns = {"owners": "max_owners", "positive_ratings": "positive_reviews",
                    "negative_ratings": "negative_reviews"}, inplace = True)

# Return the value of max_owners to return the maximum owner, instead of the range of owners
df1["max_owners"] = df1["max_owners"].apply(lambda x: x.split("-")[1])

# Create a one-hot encoder for the supported platforms of the game
df1["support_windows"] = df1["platforms"].apply(lambda x : 1 if "windows" in x else 0)
df1["support_mac"] = df1["platforms"].apply(lambda x : 1 if "mac" in x else 0)
df1["support_linux"] = df1["platforms"].apply(lambda x : 1 if "linux" in x else 0)

# Create two new columns release_year and release_month that indicates the releade year and month of the game
release_date = pd.to_datetime(df1["release_date"])
df1["release_year"] = release_date.dt.year
df1["release_month"] = release_date.dt.month

# Create a new column "is_released_on_holiday" that determines whether the game was released on a holiday month 
# or not. The holiday months are November and December. 
df1["is_released_on_holiday"] = df1["release_month"].apply(lambda x : 1 if x == 11 or x == 12 else 0)

# Drop irrelevant columns
df1 = df1.drop(columns = {"appid", "english", "required_age", "genres", "steamspy_tags", "achievements", "platforms", 
                          "release_date", "categories", "negative_reviews", "median_playtime"})

df1.head()
# Out:
#                         name         developer publisher  positive_reviews  \
# 0             Counter-Strike             Valve     Valve            124534
# 1      Team Fortress Classic             Valve     Valve              3318
# 2              Day of Defeat             Valve     Valve              3416
# 3         Deathmatch Classic             Valve     Valve              1273
# 4  Half-Life: Opposing Force  Gearbox Software     Valve              5250
#
#    average_playtime max_owners  price  support_windows  support_mac  \
# 0             17612   20000000   7.19                1            1
# 1               277   10000000   3.99                1            1
# 2               187   10000000   3.99                1            1
# 3               258   10000000   3.99                1            1
# 4               624   10000000   3.99                1            1
#
#    support_linux  release_year  release_month  is_released_on_holiday
# ...

# %%
# Shape of dataframe 1
df1.shape
# Out:
# (27075, 13)

# %% [markdown]
# ### Dataset 2

# %%
# Second dataset
df2 = pd.read_csv('steam_games.csv')

# Drop overlapping columns from the first dataframe and irrelevant columns
df2 = df2.drop(columns = {"achievements", "game_description", "mature_content", "minimum_requirements", "recommended_requirements",
                          "discount_price", "url", "types", "desc_snippet", "game_details", "genre", "release_date",
                          "developer", "publisher", "recent_reviews", "all_reviews", "original_price"})

df2.head()
# Out:
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         popular_tags  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                            languages
# 0  English,French,Italian,German,Spanish - Spain,...
# 1  English,Korean,Simplified Chinese,French,Germa...
# 2                      English,French,German,Russian
# 3  English,French,Italian,German,Spanish - Spain,...
# 4                      English,German,Russian,French

# %%
# Shape of dataframe 2
df2.shape
# Out:
# (40833, 3)

# %% [markdown]
# ## Merging the Datasets

# %%
# Merge the first and second dataframes, and set the index to the column "name"
df_final = df1.merge(df2, on = "name", how = 'inner')
df_final.set_index("name", inplace=True)

df_final.head()
# Out:
#                                   developer publisher  positive_reviews  \
# name
# Counter-Strike                        Valve     Valve            124534
# Team Fortress Classic                 Valve     Valve              3318
# Day of Defeat                         Valve     Valve              3416
# Deathmatch Classic                    Valve     Valve              1273
# Half-Life: Opposing Force  Gearbox Software     Valve              5250
#
#                            average_playtime max_owners  price  \
# name
# Counter-Strike                        17612   20000000   7.19
# Team Fortress Classic                   277   10000000   3.99
# Day of Defeat                           187   10000000   3.99
# Deathmatch Classic                      258   10000000   3.99
# Half-Life: Opposing Force               624   10000000   3.99
#
#                            support_windows  support_mac  support_linux  \
# name
# ...

# %%
# Shape of the merged dataframe
#
# Number of columns should be 15 since (14 + 3 - 1 - 1)
# where 14 is the number of columns for df1, 3 is the number of columns for df2, the first - 1 is 
# caused by the merging of the two dataframes on the column "name", and the second -1 is caused by
# column "name" becoming an index. 
df_final.shape
# Out:
# (19649, 14)

# %% [markdown]
# ## One-Hot Encoding

# %% [markdown]
# We will be one hot encoding the columns popular_tags, languages, developer, and publisher. Each of these columns include categorical data, which needs to be altered into values of 0 or 1. We need to change them into a numeric variable so that the common machine learning algorithms can be applied effectively. Each of the columns provide an attribute of the game that can be used as a feature to predict the target variable.

# %% [markdown]
# ### Popular Tags

# %%
# Create a dataframe for the popular tags by splitting the tags in the column "popular_tags" 
# into dummy variables. Then delete the column in the merged dataframe. Use the same method for 
# the languages column. 
popular_tags_df = df_final["popular_tags"].str.get_dummies(sep= ',')
df_final = df_final.drop(columns = {"popular_tags"})
popular_tags_df.head()
# Out:
#                            1980s  1990's  2.5D  2D  2D Fighter  360 Video  3D  \
# name
# Counter-Strike                 1       1     0   0           0          0   0
# Team Fortress Classic          0       1     0   0           0          0   0
# Day of Defeat                  0       0     0   0           0          0   0
# Deathmatch Classic             0       0     0   0           0          0   0
# Half-Life: Opposing Force      0       1     0   0           0          0   0
#
#                            3D Platformer  3D Vision  4 Player Local  ...  \
# name                                                                 ...
# Counter-Strike                         0          0               0  ...
# Team Fortress Classic                  0          0               0  ...
# Day of Defeat                          0          0               0  ...
# Deathmatch Classic                     0          0               0  ...
# ...

# %%
# Shape of the popular_tags_df
# Row represents the number of unique games
# Column represents the number of unique tags used by Steam for any game
popular_tags_df.shape
# Out:
# (19649, 376)

# %%
# Merge popular_tags_df to the final dataset
df_final = pd.concat([df_final, popular_tags_df], axis=1)
df_final.head()
# Out:
#                                   developer publisher  positive_reviews  \
# name
# Counter-Strike                        Valve     Valve            124534
# Team Fortress Classic                 Valve     Valve              3318
# Day of Defeat                         Valve     Valve              3416
# Deathmatch Classic                    Valve     Valve              1273
# Half-Life: Opposing Force  Gearbox Software     Valve              5250
#
#                            average_playtime max_owners  price  \
# name
# Counter-Strike                        17612   20000000   7.19
# Team Fortress Classic                   277   10000000   3.99
# Day of Defeat                           187   10000000   3.99
# Deathmatch Classic                      258   10000000   3.99
# Half-Life: Opposing Force               624   10000000   3.99
#
#                            support_windows  support_mac  support_linux  \
# name
# ...

# %% [markdown]
# ### Languages

# %%
languages_df = df_final["languages"].str.get_dummies(sep= ',')
df_final = df_final.drop(columns = {"languages"})
languages_df.head()
# Out:
#                             Bulgarian   Czech   Danish   Dutch   Finnish  \
# name
# Counter-Strike                      0       0        0       0         0
# Team Fortress Classic               0       0        0       0         0
# Day of Defeat                       0       0        0       0         0
# Deathmatch Classic                  0       0        0       0         0
# Half-Life: Opposing Force           0       0        0       0         0
#
#                             French   German   Greek   Hungarian   Italian  \
# name
# Counter-Strike                   0        0       0           0         0
# Team Fortress Classic            0        0       0           0         0
# Day of Defeat                    0        0       0           0         0
# Deathmatch Classic               0        0       0           0         0
# Half-Life: Opposing Force        0        0       0           0         0
#
#                            ...  Simplified Chinese  Slovakian  \
# ...

# %%
# Shape of the languages_df
# Row represents the number of unique games
# Column represents the number of unique languages supported for any game
languages_df.shape
# Out:
# (19649, 60)

# %%
# Merge languages_df to the final dataset
df_final = pd.concat([df_final, languages_df], axis=1)
df_final.head()
# Out:
#                                   developer publisher  positive_reviews  \
# name
# Counter-Strike                        Valve     Valve            124534
# Team Fortress Classic                 Valve     Valve              3318
# Day of Defeat                         Valve     Valve              3416
# Deathmatch Classic                    Valve     Valve              1273
# Half-Life: Opposing Force  Gearbox Software     Valve              5250
#
#                            average_playtime max_owners  price  \
# name
# Counter-Strike                        17612   20000000   7.19
# Team Fortress Classic                   277   10000000   3.99
# Day of Defeat                           187   10000000   3.99
# Deathmatch Classic                      258   10000000   3.99
# Half-Life: Opposing Force               624   10000000   3.99
#
#                            support_windows  support_mac  support_linux  \
# name
# ...

# %% [markdown]
# ### Developer

# %%
# Create a dataframe for the developers by splitting the tags in the column "developer" 
# into dummy variables. Then delete the column in the merged dataframe. Use the same method for 
# the publisher column. 
developer_df = pd.get_dummies(df_final["developer"])
df_final = df_final.drop(columns = {"developer"})
developer_df.head()
# Out:
#                            #workshop  'What Day is it?' Games  \
# name
# Counter-Strike                     0                        0
# Team Fortress Classic              0                        0
# Day of Defeat                      0                        0
# Deathmatch Classic                 0                        0
# Half-Life: Opposing Force          0                        0
#
#                            (STCG) Smoker The Car Game  +7 Software  \
# name
# Counter-Strike                                      0            0
# Team Fortress Classic                               0            0
# Day of Defeat                                       0            0
# Deathmatch Classic                                  0            0
# Half-Life: Opposing Force                           0            0
#
#                            +Mpact Games, LLC.  .ez Games  07th Expansion  \
# name
# Counter-Strike                              0          0               0
# ...

# %%
# Shape of the developer_df
# Row represents the number of unique games
# Column represents the number of unique developers for any game
developer_df.shape
# Out:
# (19649, 13020)

# %%
# Merge developer_df to the final dataset
df_final = pd.concat([df_final, developer_df], axis=1)
df_final.head()
# Out:
#                           publisher  positive_reviews  average_playtime  \
# name
# Counter-Strike                Valve            124534             17612
# Team Fortress Classic         Valve              3318               277
# Day of Defeat                 Valve              3416               187
# Deathmatch Classic            Valve              1273               258
# Half-Life: Opposing Force     Valve              5250               624
#
#                           max_owners  price  support_windows  support_mac  \
# name
# Counter-Strike              20000000   7.19                1            1
# Team Fortress Classic       10000000   3.99                1            1
# Day of Defeat               10000000   3.99                1            1
# Deathmatch Classic          10000000   3.99                1            1
# Half-Life: Opposing Force   10000000   3.99                1            1
#
# ...

# %% [markdown]
# ### Publisher

# %%
publisher_df = pd.get_dummies(df_final["publisher"])
df_final = df_final.drop(columns = {"publisher"})
publisher_df.head()
# Out:
#                                AFBIK Studio   AYE Technology   Asterion Games  \
# name
# Counter-Strike             0              0                0                0
# Team Fortress Classic      0              0                0                0
# Day of Defeat              0              0                0                0
# Deathmatch Classic         0              0                0                0
# Half-Life: Opposing Force  0              0                0                0
#
#                             Aurora software   Big Fish Games  \
# name
# Counter-Strike                            0                0
# Team Fortress Classic                     0                0
# Day of Defeat                             0                0
# Deathmatch Classic                        0                0
# Half-Life: Opposing Force                 0                0
#
#                             Black Poodle Entertainment   Boogygames Studios  \
# name
# ...

# %%
# Shape of the publisher_df
# Row represents the number of unique games
# Column represents the number of unique publishers for any game
publisher_df.shape
# Out:
# (19649, 10866)

# %%
# Merge publisher_df to the final dataset
df_final = pd.concat([df_final, publisher_df], axis=1)
df_final.head()
# Out:
#                            positive_reviews  average_playtime max_owners  \
# name
# Counter-Strike                       124534             17612   20000000
# Team Fortress Classic                  3318               277   10000000
# Day of Defeat                          3416               187   10000000
# Deathmatch Classic                     1273               258   10000000
# Half-Life: Opposing Force              5250               624   10000000
#
#                            price  support_windows  support_mac  support_linux  \
# name
# Counter-Strike              7.19                1            1              1
# Team Fortress Classic       3.99                1            1              1
# Day of Defeat               3.99                1            1              1
# Deathmatch Classic          3.99                1            1              1
# Half-Life: Opposing Force   3.99                1            1              1
#
# ...

# %%
# Get rid of max_owners column. Keep the dataframe with max_owners seperate. 
df_final_with_max_owners = df_final
df_final = df_final.drop(columns=["max_owners"])

# %%
# Create a column "avg_num_of_positive_reviews_per_year" which indicates the average number of positive reviews per year. 
# This column nullifies the bias towards games that are released earlier compared to games that are released recently. 
# Games that has been on sale longer has more chances to have a positive review. Make this dataframe seperate from df_final
df_final["avg_num_of_positive_reviews_per_year"] = df_final["positive_reviews"] / (2020 - df_final["release_year"])
df_final_with_avg_pos_reviews = df_final

df_final.drop(columns=["avg_num_of_positive_reviews_per_year"])

df_final_with_avg_pos_reviews.haed()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-81bcaed4f7bc> in <module>
#       7 df_final.drop(columns=["avg_num_of_positive_reviews_per_year"])
#       8
# ----> 9 df_final_with_avg_pos_reviews.haed()
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'haed'

# %% [markdown]
# ## Target & Feature

# %%
# Set target and features where the target is the positive_reviews
target_positive_reviews = df_final["positive_reviews"]
features_positive_reviews = df_final.drop("positive_reviews", axis = 1)

# %% [markdown]
# ## RUBRIC
# In this section, you should do the following and explain why you are doing what you are doing. For each, you should include your code in a cell, followed by a sample output. For instance, if you are one-hot encoding one of your variables, you should first describe what it is and why you are doing it. You should then include your code in a cell, and the sample output should be available as well.
#
# * Perform simple data cleaning (delete extra columns, deal with NA values, etc.)
# * Perform data wrangling to get your features and target values (e.g., grouping your dataframe by columns, applying functions to format dataframes, etc.)
# * Preprocess your variables (e.g., scaling/transforming feature variables to normalize them)
# * Perform feature extraction (dummy variables, new features from existing features, etc.)
# * Use one feature selection technique to select a subset of your original features

# %% [markdown]
# ### 3.2. Data Exploration
#
# ## RUBRIC
# * Generate appropriate data visualizations for your key variables identified in the previous section
# * You should have at least three visualizations (and at least two different visualization types)
# * For each visualization provide an explanation regarding the variables involved and an interpretation of the graph.
# * If you are using Plotly, insert your visualizations as images as well (upload the graph images to an online source, e.g. github, and embed those into the cells in Jupyter Notebook)

# %% [markdown]
# ### 3.3. Model Construction
#
# ## RUBRIC
# * Conduct your hypothesis test(s) here.
# * For your machine learning question(s), use the Training, Validation, and Testing approach through GridSearch
# * Apply machine learning algorithms (apply at least three different algorithms)
# * Train your algorithms

# %% [markdown]
# ### 3.4. Model Evaluation
#
# ## RUBRIC
# * Evaluate the performance of your algorithms on appropriate evaluation metrics, using your validation set
#     * Use at least two different metrics
# * Evaluate your results from multiple ML models and hypothesis tests
#     * What was the performance of each algorithm in plain English? Is there any indication of overfitting/underfitting?
#     * Was there a significant difference? Use the template from lecture slides when reporting the results of your hypothesis testing.

# %% [markdown]
# ### 3.5. Model Optimization
#
# # RUBRIC
# * Tune your models using appropriate hyperparameters
# * Explain why you are doing this (e.g., to avoid overfitting, etc.)

# %% [markdown]
# ### 3.6. Model Testing
#
# ## RUBRIC
# * Test your tuned algorithms using your testing set

# %% [markdown]
# <a id="4"></a>
# <hr style="height:2px; border:none; color:black; background-color:black;">

# %% [markdown]
# ## 4. DISCUSSION
# * Provide a summary of the steps you took to analyze your data and test your predictive model
# * Interpret your findings from 3.4., 3.5, and 3.6
#     * Which algorithms did you compare?
#     * Which algorithm(s) revealed best performance?
#     * Which algorithm(s) should be used for your predictive model?
#     * Based on your findings, can we you the features in your dataset to predict the outcome variable you identified using the algorithms you've applied? (It is okay if the answer is no. We're interested in the process, not the performance of the model.)
# * For your hypotheses, interpret the results. What does it mean to have significant/non-significant differences with regards to your data?
#
#
# * End this section with a conclusion paragraph containing some pointers for future work
#     * (e.g., get more data/features, perform another analysis, etc.)

# %% [markdown]
# <a id="5"></a>
# <hr style="height:2px; border:none; color:black; background-color:black;">

# %% [markdown]
# ### CONTRIBUTIONS
# * Describe each team member's contributions to the report (who did what in each section)
# * Remember this is a team effort!
# * Each member of your team will provide peer evaluation of other team members. Your final grade on the project will be based on those peer evaluations. An survey will be shared after the deadline for this deliverable.

# %%
# anova/f-test for hypothesis testing
# for anova testing use the value num_pos_reviews/(current year - year released) (which is avg num of reviews per year)
# we're doing this cuz it makes it more unbiased towards games that are released more recently. Games that has been on sale 
# longer has more chances to have a positive review. 

# developer / publisher barplot with pos.reviews (make 2)

# %%
# Lasso regression. Do a hypothesis testing still. No need to imply t values, f test to reject hypothesis or anything like that. 
# Lasso shrinks smaller coeff to 0 (irrelevant). Lasso can be used as a feature selectoin method as well. 
# Look at r^2 values. Adjusted r^2 values? Closer to 1, the more accurate the model is. 

# Do Lasso first, then compare with other models! (like Ridge). But ultimately we should use Lasso.
# correlation analysis

# %%
# dont use max_owners as feature in model. But use it for hypotehsis testing.

# %%
# correlatoinal analysis if possible
# mutual information - feature selection method.

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(features_positive_reviews, target_positive_reviews, random_state=3000)


model = Lasso(alpha = 0.01).fit(X=X_train, y=y_train)


print("R-squared value for training set: ", r2_score(y_train, model.predict(X_train)))
print("R-squared value for testing set: ", r2_score(y_test, model.predict(X_test)))

# %%
# import plotly.express as px

# fig = px.bar(df_final, x='developer', y='Potion_Ave', title="House Points", color="Quidditch", barmode="group")

# fig.show()

# %%
df1["publisher"].value_counts()
